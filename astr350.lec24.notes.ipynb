# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 24
#
#
# ### Prof. Robert Quimby <br> April 16, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Active Listening and Feedback

# %% [markdown]
# Download now:
# - https://classroom.github.com/a/2Tse1ti2
