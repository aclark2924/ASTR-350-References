# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
# reset defalult plotting values
plt.rcParams['figure.figsize'] = (10, 7)
plt.rc('font', family='sans-serif')
plt.rc('axes', labelsize=14)
plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=16)
plt.rc('axes', titleweight='bold')

# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 20
#
#
# ### Prof. Robert Quimby <br> March 26, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Quiz 15 review

# %% [markdown]
# ## `astroquery`

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/astroquery.ipynb)
# - [video](https://youtu.be/lC8yl5LUhgU) (24 min)

# %%
import astroquery

# %% [markdown]
# ## SIMBAD

# %% [markdown]
# ![SIMBAD](https://cds.unistra.fr/img/cds/simbad.svg)

# %% [markdown]
# * http://simbad.u-strasbg.fr/simbad/

# %% [markdown]
# ## NED

# %% [markdown]
# ![NED](http://ned.ipac.caltech.edu/pics/NEDLogo.png)

# %% [markdown]
# * http://ned.ipac.caltech.edu/

# %% [markdown]
# ## VizieR

# %% [markdown]
# ![VizieR logo](https://cds.unistra.fr/img/cds/vizier.svg)

# %% [markdown]
# - http://vizier.u-strasbg.fr/viz-bin/VizieR (main server)
# - http://vizier.cfa.harvard.edu/index.gml (server mirror at CfA)

# %% [markdown]
# ## Find precise positions of Barnard's star in the USNO-A2.0 catalog

# %% [markdown]
# ### approximate position (from prior quiz)
# POSS1:
# - ra, dec ~ 269.46296, 4.5516963

# %%
# use astroquery to find Barnard's star in the USNO-A2.0 catalog
from astroquery.????
from astropy.coordinates import SkyCoord
import astropy.units as u

????

# %% [markdown]
# ## ADS

# %% [markdown]
# - https://ui.adsabs.harvard.edu/

# %% [markdown]
# ## ADS paper lookup example

# %% [markdown]
# Say you are reading this paper:
# - https://ui.adsabs.harvard.edu/abs/2020MNRAS.491.2465K/abstract
#
# And you see this citation in the text:
# - "(Barnard 1916)"
#
# You check the References section at the end of the paper to find the bibliographic information for this citation, which is:
# - "Barnard E. E., 1916, AJ, 29, 181"
#
# How do you get a copy of that cited paper to review?

# %% [markdown]
# ### Search ADS!
# - https://ui.adsabs.harvard.edu/

# %% [markdown]
# ![announcement of Barnard's Star](media/barnards_paper.png)

# %% [markdown]
# ## Find a galaxy identifier (name)

# %%
image = fits.getdata('media/example.fits')
vmin, vmax = np.percentile(image, (2, 98))
plt.imshow(image, origin='lower', vmin=vmin, vmax=vmax);

# %% [markdown]
# ## Are you getting this?

# %% [markdown]
# Do not download until told to do so:
# - https://classroom.github.com/a/dKOzykCS

# %% [markdown]
# ## Homework

# %% [markdown]
# - [homework #10](../homework/astr350.hw10.ipynb)
