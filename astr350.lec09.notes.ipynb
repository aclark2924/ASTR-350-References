# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
# reset defalult plotting values
plt.rcParams['figure.figsize'] = (15, 5)
plt.rc('font', family='sans-serif')
plt.rc('axes', labelsize=14)
plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=16)
plt.rc('axes', titleweight='bold')
plt.rc('axes', linewidth=2)

# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 9
#
#
# ### Prof. Robert Quimby <br> February 17, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Saturday Observing

# %% [markdown]
# - Directions to MLO given the "MLO_risks.pdf"
# - [Current view of MLO](https://www.hpwren.ucsd.edu/alpha/cameras/#mode=realTime&cams=mlo_mlo-n-mobo-m.mlo_mlo-e-mobo-m.mlo_mlo-s-mobo-m.mlo_mlo-w-mobo-m.mlo_mlo-n-mobo-c.mlo_mlo-e-mobo-c.mlo_mlo-s-mobo-c.mlo_mlo-w-mobo-c.mlo_mlo-n-axis.mlo_mlo-s-axis&realTimeShowType=&iifi=mlo_mlo-n-mobo-c)
# - [10 day forecast](https://www.wunderground.com/forecast/us/ca/mount-laguna)

# %% [markdown]
# - Pick a target to observe
#   - check with [Stellarium](http://stellarium.org)
# - what is the Moon's phase?

# %% [markdown]
# ## Quiz-6 review

# %% [markdown]
# ## Central Limit Theorm

# %% [markdown]
# If we record $N$ sums of $N$ different samples then the distribution of these sums will become Gaussian in the limit $N \rightarrow \infty$
#
# See
# - https://en.wikipedia.org/wiki/Central_limit_theorem
# - [Central Limit Theorm](https://ebookcentral.proquest.com/lib/sdsu/reader.action?docID=691865&ppg=162) as presented in, "A Student's Guide to Data and Error Analysis," by Herman J. C. Berendsen

# %% [markdown]
# ## Telescopes

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/telescopes.ipynb)
# - [video](https://youtu.be/EVSzPhVO2NI)

# %% [markdown]
# ## Telescope Mounts

# %% [markdown]
# ### Alt-Az Mounts

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('pKg4wkcqMWU', start=3, end=16, iv_load_policy=3, rel=0, showinfo=0)

# %% [markdown]
# ### Equitorial Mounts

# %%
YouTubeVideo('KJ3FudCSoOU', start=3, end=16, iv_load_policy=3, rel=0, showinfo=0)

# %% [markdown]
# ## Right Ascention and Declination

# %% [markdown]
# ![RA/Dec coordinate system; figure adapted from ????](media/ra_dec_coord.png)

# %% [markdown]
# ## Local Sidereal Time

# %% [markdown]
# The Right Ascension of a objects on the meridian.
#
# - Wikipedia article on [sidereal time](https://en.wikipedia.org/wiki/Sidereal_time)

# %% [markdown]
# ## Changing coordinate systems

# %% [markdown]
# **Q:** What is the current altitude of the Sun?

# %%
# start with the current RA, Dec of the Sun
from astropy.time import Time
from astropy.coordinates import get_body

????

# %%
# convert to the Alt-Az system
import astropy.units as u
from astropy.coordinates import EarthLocation, AltAz

latitude = 32.842167 * u.deg
longitude = -116.426938 * u.deg
elevation = 1860 * u.m
mlo = EarthLocation.from_geodetic(longitude, latitude, elevation)

????

# %% [markdown]
# ## Are you getting this?

# %% [markdown]
# Do not download until instructed to do so:
# - https://classroom.github.com/a/nV30XZs4
