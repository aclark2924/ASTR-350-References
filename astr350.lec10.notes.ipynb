# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
# reset defalult plotting values
plt.rcParams['figure.figsize'] = (15, 5)
plt.rc('font', family='sans-serif')
plt.rc('axes', labelsize=14)
plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=16)
plt.rc('axes', titleweight='bold')

# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 10
#
#
# ### Prof. Robert Quimby <br> February 19, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Quiz-7 review

# %% [markdown]
# ## Oral Presentation Sign-Up

# %% [markdown]
# ## CCDs

# %% [markdown]
# - [notebook](../tutorials/ccd.ipynb)
# - [video](https://youtu.be/hT0bhLqw9tE) (28 min)

# %% [markdown]
# [CCD Demonstrator](https://rquimby.sdsu.edu/ccd.html)

# %% [markdown]
# ## Imagine a CCD image Taken with the Shutter Closed

# %% [markdown]
# What do you expect the pixel values to be?

# %%
# load the image data
image = fits.getdata(????)

# %%
# show the image
plt.figure(figsize=(8, 8))
vmin = ????
vmax = ????
plt.imshow(image, vmin=vmin, vmax=vmax);

# %%
# plot the distribution of pixel values
plt.hist(image.flatten(), bins=100, range=(vmin, vmax));

# %% [markdown]
# ## Relation Between Incident Photons and ADU

# %% [markdown]
# For each pixel (ignoring noise for the moment),
# $$C = { (B_f + B_s + \epsilon N_{\gamma}) \over g}$$
# where:
# * $C =$ the "counts" in ADU recorded for a given pixel
# * $B_f =$ time dependant (floating) bias (measured in $e^-$)
# * $B_s =$ time independant (static) bias floating bias (measured in $e^-$)
# * $\epsilon =  $ photon conversion efficiency ($e^- /$ photon incident on aperature)
# * $N_{\gamma} =$ number of incident photons
# * $g =  $ "gain" (in $e^- / {\rm ADU}$)

# %% [markdown]
# ## Overscan

# %% [markdown]
# * After each CCD row is read out, the serial register is clocked several more times to generate virtual pixels
# * These are used to measure the time dependant bias level

# %%
# check the number of rows and columns in the image
ny, nx = image.shape
print(f'{ny} rows and {nx} columns')

# %%
plt.figure(figsize=(8,8))
plt.imshow(image, cmap='gray', origin='lower', vmin=vmin, vmax=vmax);
plt.axvspan(ny, nx-1, alpha=0.25, color='red')
plt.text( (nx + ny) / 2, ny / 2, 'Overscan', fontsize=24, fontweight='bold'
         , color='r', rotation=90, ha='center', va='center')
plt.xlabel('Column Number')
plt.ylabel('Row Number');

# %% [markdown]
# ## Are you getting this?

# %% [markdown]
# Do not download until instructed to do so:
# - https://classroom.github.com/a/Kvb-G1vV

# %% [markdown]
# ## Homework for next week

# %% [markdown]
# - [homework #5](../homework/astr350.hw05.ipynb)
