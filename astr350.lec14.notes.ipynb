# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from astropy.coordinates import SkyCoord

# %%
# reset defalult plotting values
plt.rcParams['figure.figsize'] = (8, 6)
plt.rc('font', family='sans-serif')
plt.rc('axes', labelsize=14)
plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=16)
plt.rc('axes', titleweight='bold')

# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 14
#
#
# ### Prof. Robert Quimby <br> March 6, 2025
#
# &copy; 2025 Robert Quimby

# %% [markdown]
# ## Review Quiz 10

# %% [markdown]
# ## Propagation of Uncertainty

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/uncertainty.propagation.ipynb)
# - [video](https://youtu.be/63qgB253REk) (10 min)

# %% [markdown]
# #### Recall:
# Given a function $f$ of several variables, $x_0, x_1 ... x_{n-1}$, if the variables have random, **independent** uncertainties, $\sigma_{x_0}, \sigma_{x_1} ... \sigma_{x_{n-1}}$, then the uncertainty in the function, $\sigma_f$, is:
#
# $$ \sigma_f = \sqrt{ \left( {\partial f \over \partial x_0 }\sigma_{x_0}\right)^2
#                    + \left( {\partial f \over \partial x_1 }\sigma_{x_1}\right)^2
#                    + ...
#                    + \left( {\partial f \over \partial x_n }\sigma_{x_{n-1}}\right)^2
#                     } $$

# %%
def f(x):
    y = ????
    return y

# %%
xs = np.linspace(2, 4, 10)
ys = f(xs)

#x = ????
#dx = ????
#y1, y2 = f(x - dx), f(x + dx)

plt.plot(xs, ys)
#plt.plot([x - dx, x + dx], [y1, y2], c='r', lw=3);
plt.axis('equal')
plt.grid();

# %% [markdown]
# ## Example 1: uncertainty in the average of N measurements

# %% [markdown]
# You draw $N$ samples from a Gaussian distribution with a mean of $\mu$ and a standard deviation of $\sigma$.
#
# - What do you expect the average value of the $N$ samples to be? Due to random chance, the actual average you get from an experiment may be larger or smaller than this expected value.
# - What is the expected uncertainty in the average?

# %% [markdown]
# ## How do we solve this?

# %% [markdown]
# Start with the equation for the average:
# $$A = {1 \over N}\sum_{i=0}^{N-1} x_i$$
# or
# $$A = {x_0 \over N} + {x_1 \over N} + \dots$$

# %% [markdown]
# Now apply the uncertainty propagation formula:
#
# $$ \sigma_A = \sqrt{ \left({\partial A \over \partial x_0 }\sigma_{x_0}\right)^2
# + \left({\partial A \over \partial x_1 }\sigma_{x_1}\right)^2
# + \dots
# }$$

# %% [markdown]
# If all of the $\sigma_{x_i}$ have the same uncertainty, $\sigma$, then we have:
# $$ \sigma_A = ????$$
# or simply
# $$ \sigma_A = ????$$

# %% [markdown]
# ## Example 2

# %% [markdown]
# Given a flux, $f$, with an uncertainty, $\sigma_f$, and the magnitude definition, $m = m_{zp} - 2.5\log_{10}(f)$,
# plot the magnitude uncertainty, $\sigma_m$, as a function of the "signal-to-noise ratio", $f / \sigma_f$.

# %% [markdown]
# ## How do we solve this?

# %% [markdown]
# Use propagation of uncertainty to determine how changes in magnitude uncertainty, $\sigma_m$, relate to changes in flux uncertainty, $\sigma_f$

# %% [markdown]
# Using the definition of magnitude, we have:
#
# $$ \sigma_m = \sqrt{ \left( {\partial m \over \partial f }\sigma_{f}\right)^2 } $$

# %% [markdown]
# So what is ${\partial m \over \partial f }$?

# %% [markdown]
# $${\partial m \over \partial f } = ????$$

# %% [markdown]
# Putting this all together, we have
#
# $$\sigma_m = ????$$

# %% [markdown]
# ## Now we can make the plot

# %%
s2n = ????

sigma_m = ????

plt.plot(s2n, sigma_m)
plt.xlabel('Signal-to-noise ratio')
plt.ylabel('magnitude uncertainty (mag)')
plt.grid();

# %% [markdown]
# ## Are you getting this?

# %% [markdown]
# Do not download until told to do so:
# - https://classroom.github.com/a/T0voA63j

# %% [markdown]
# ## Homework #7

# %% [markdown]
# * [Homework #7](../homework/astr350.hw07.ipynb)
