# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 6
#
#
# ### Prof. Robert Quimby <br> February 5, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Schopp Lecture

# %% [markdown]
# Wednesday, February 18th 2026 at 7:00PM, NE 60

# %% [markdown]
# ## MLO 1.0m Observing

# %% [markdown]
# - Scheduled for February 21 (Saturday) starting at 5:00pm (sunset is around 5:40pm)
#
# - Liability waiver form
#     - https://bfa.sdsu.edu/safety/riskmanagement/docs/release-liability-waiver-2022.pdf
# - Additional Risks and Dangers form, MLO_risks.pdf, in your lectures/media/ folder
# - sign and submit both forms by Feb 18 (Wed.)

# %% [markdown]
# ## Working with FITS images in Python

# %%
# setup plotting
import matplotlib.pyplot as plt

# %%
# load the image data
from astropy.io import fits
image = ????

# %%
# display using matplotlib
plt.????

# %% [markdown]
# ## FITS files can store data tables too!

# %%
# load photometry catalog
phot = ????

# %%
# show positions of objects (matplotlib version)
????

# %% [markdown]
# ## You can also use JS9 to view FITS images

# %% [markdown]
# - Visit the [JS9](https://js9.si.edu/) web site
# - In JS9, to display a FITS image saved to your computer (not on the JupyterHub!):
#   - File --> open local

# %% [markdown]
# ## Quiz-4 review

# %% [markdown]
# * [blank](../github/quizzes/quiz-04/astr350.qz04.ipynb)
# * [complete](../quizzes/astr350.qz04.ipynb)
# * [scratch](../quizzes/astr350.qz04.scratch.ipynb)

# %% [markdown]
# ## Palomar Transient Factory

# %% [markdown]
# - [about](https://www.ptf.caltech.edu/)
# - [image server](https://irsa.ipac.caltech.edu/applications/ptf/)

# %% [markdown]
# ## Proper Motion

# %% [markdown]
# ![proper motion diagram; RQ](media/proper_motion.png)

# %% [markdown]
# ## Midterm Project 1

# %% [markdown]
# Assignment link:
# - https://classroom.github.com/a/DomgU1PX

# %% [markdown]
# ## Coordinate Matching

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/coordinate.matching.ipynb)
# - [solved](../tutorials/coordinate.matching.solved.ipynb)
# - [video](https://youtu.be/iE5fhebaxSo) (28 min)

# %% [markdown]
# ## Homework

# %% [markdown]
# * [homework #3](../homework/astr350.hw03.ipynb)
