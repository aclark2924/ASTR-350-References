# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats
from astropy.io import fits
from astropy.coordinates import SkyCoord

# %%
# reset defalult plotting values
plt.rcParams['figure.figsize'] = (10, 5)
plt.rc('font', family='sans-serif')
plt.rc('axes', labelsize=14)
plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=16)
plt.rc('axes', titleweight='bold')

# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 13
#
#
# ### Prof. Robert Quimby <br> March 3, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Quiz 9 review

# %% [markdown]
# ## $\LaTeX$

# %% [markdown]
# Tutorial
#   - [notebook](../tutorials/latex.ipynb)
#   - [video](https://youtu.be/rEpVJueiUBc)

# %% [markdown]
# ## Create a $\LaTeX$ document on Overleaf.com

# %% [markdown]
# https://www.overleaf.com/

# %% [markdown]
# ## Magnitudes

# %% [markdown]
#  Tutorial
# - [notebook](../tutorials/magnitudes.ipynb)
# - [video](https://youtu.be/yf_pI8yx5-w) (20 min)

# %% [markdown]
# ## Synthetic Photometry

# %% [markdown]
# $$m_{\rm Vega}^{\rm obj} = -2.5 \log_{10} \left( {\int f_{\lambda}^{\rm obj} \lambda T_{\lambda} d\lambda \over \int f_{\lambda}^{\rm Vega} \lambda T_{\lambda} d\lambda} \right)$$
#
# $f_\lambda$ in erg s$^{-1}$ cm$^{-2}$ &Aring;$^{-1}$

# %%
vega = np.genfromtxt('media/vega_flam.dat', names='wav, flam')
plt.plot(vega['wav'], vega['flam'], c='k')

filt = 'B'
band = np.genfromtxt(f'media/John_{filt}.dat', names=('wav', 'T'))
band['T'] /= band['T'].max() / 0.4
wuse = band['T'] > 0
#plt.plot(band['wav'], band['T'] * vega['flam'].max(), c=f'C3')

plt.xlim(3000, 9000)
plt.grid();

# %% [markdown]
# ## Are you getting this?

# %% [markdown]
# Do not download until told to do so:
# - https://classroom.github.com/a/pLIZERka
