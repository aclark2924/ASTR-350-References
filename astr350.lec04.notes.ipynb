# %% [markdown]
# # ASTR 350: Astronomical Techniques
# # Lecture 4
#
#
# ### Prof. Robert Quimby <br> January 29, 2026
#
# &copy; 2026 Robert Quimby

# %% [markdown]
# ## Quiz-02 review

# %% [markdown]
# ## Numpy

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/numpy.ipynb)
# - [video](https://youtu.be/_-K9YZ0-3IE) (25 min)

# %%
x = 5
y = x
x, y

# %%
import ????

# %% [markdown]
# ## Loading data from a file with `numpy`

# %%
# load the data
data = ????

# %%
# load the data into a structured array
data = ????

# %%
# numpy arrays have built-in (universal) functions for convenience

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/matplotlib.ipynb)
# - [video](https://youtu.be/6h_L8lkOyHU) (15 min)

# %%
# import matplotlib
import ????

# %%
# plot the data

# %%
# plot a sine wave from phases −2𝜋 to 2𝜋

# %% [markdown]
# ## Python Debugger

# %% [markdown]
# Tutorial
# - [notebook](../tutorials/python.debugger.ipynb)
# - [video](https://youtu.be/JSrSnyYelEU) (10 min)

# %% [markdown]
# ## Are you getting this?

# %% [markdown]
# Do not download until instructed to do so:
# - https://classroom.github.com/a/FV01MEpo

# %% [markdown]
# ## For next time: DS9 $\rightarrow$ JS9

# %% [markdown]
# - [DS9](https://sites.google.com/cfa.harvard.edu/saoimageds9) is a stand-alone program for viewing FITS images
# - JS9 is similar to DS9 but it runs in a web browser:
#   - https://js9.si.edu/

# %% [markdown]
# ## Homework for next week

# %% [markdown]
# - [homework #2](../homework/astr350.hw02.ipynb) (you may need to `git pull` in your homework repo)
